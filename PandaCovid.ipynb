# %% [markdown]
# <a href="https://colab.research.google.com/github/sulemantech/12v12/blob/master/PandaCovid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import urllib.request

# Define the dataset folder and the file path
dataset_folder_path = 'dataset/'
file_path = os.path.join(dataset_folder_path, 'italy_total.csv')

# Create the dataset folder if it doesn't exist
if not isdir(dataset_folder_path):
    os.makedirs(dataset_folder_path)

# URL to download the CSV file
url = 'https://github.com/RamiKrispin/covid19Italy/raw/master/csv/italy_total.csv'

# Download the file
urllib.request.urlretrieve(url, file_path)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the column sum of nan
print(df.isnull().sum())

# Display the dimension
print(df.shape)

# Display the first few rows of the DataFrame
print(df.head())

#Relating the variables in scatterplot
sns.relplot(x="total_tests",y="recovered", data=df)
plt.show()

sns.relplot(x="total_tests",y="death", data=df)
plt.show()

# Display DataFrame info
print(df.info())

# Display statistical description of the DataFrame
print(df.describe())
# Out:
# date                                   0
# hospitalized_with_symptoms             0
# intensive_care                         0
# total_hospitalized                     0
# home_confinement                       0
# cumulative_positive_cases              0
# daily_positive_cases                   0
# recovered                              0
# death                                  0
# positive_clinical_activity           969
# positive_surveys_tests               969
# cumulative_cases                       0
# total_tests                            0
# total_people_tested                   55
# new_intensive_care                   283
# total_positive_molecular_test        326
# total_positive_rapid_antigen_test    326
# molecular_test                       326
# rapid_antigen_test                   326
# dtype: int64
# (1131, 19)
#          date  hospitalized_with_symptoms  intensive_care  total_hospitalized  \
# ...
